# %%
# !git clone https://github.com/SarahLeCorre/DataMining.git
# Out:
# Cloning into 'DataMining'...
# remote: Enumerating objects: 782, done.
# remote: Counting objects: 100% (782/782), done.
# remote: Compressing objects: 100% (780/780), done.
# remote: Total 782 (delta 0), reused 782 (delta 0), pack-reused 0
# Receiving objects: 100% (782/782), 8.67 MiB | 15.46 MiB/s, done.
